# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ## Data Science Tools and Ecosystem
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# ## Data Science Languages
# Python, R, and Julia are three of the most popular programming languages
# for data science.
#
# - **Python** is a general-purpose programming language that is known for
# its simplicity and flexibility. It has a large and active community of
# developers, and there are many libraries available for Python that are
# specifically designed for data science tasks.
#
# - **R** is a statistical programming language that is known for its rich
# set of statistical functions. It is popular among statisticians and data
# scientists for its ability to perform complex statistical analyses.
#
# - **Julia** is a newer programming language that is gaining popularity in
# the data science community. It is known for its speed and efficiency,
# and it has a syntax that is similar to Python.

# %% [markdown]
# | Tool         | Description                   |
# |--------------|-------------------------------|
# | Jupyter      | Interactive notebooks         |
# | TensorFlow   | Open-source machine learning  |
# | Scikit-Learn | Machine learning in Python    |

# %% [markdown]
# ## Data Science Libraries
# * **NumPy** is a Python library that provides a multidimensional array
# object and useful mathematical functions.
#
# * **Pandas** is a Python library that provides data structures and data
# analysis tools.
#
# * **Matplotlib** is a Python library that provides 2D and 3D plotting
# capabilities.

# %% [markdown]
# ### Mathematical Expressions
#
# Examples of mathematical expressions:
#
# * \(2 + 2 = 4\)
# * \(3 \times 5 = 15\)
# * \(x^2 = x \times x\)

# %% [markdown]
# ```python
# num1 = 5
# num2 = 3
# result = num1 * num2 + num1
# print(result)
# ```

# %% [markdown]
# ```python
# minutes = 200
# hours = minutes / 60
#
# hours
# ```

# %% [markdown]
# ## Objectives
#
# - List popular languages for Data Science.
# - Introduce common Data Science tools and libraries.
# - Provide examples of mathematical expressions.
# - Demonstrate simple Python code for arithmetic operations.
# - Convert units from minutes to hours.

# %% [markdown]
# **## Author
# ABDULLAH ALMONEEF**
